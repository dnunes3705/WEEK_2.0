# %%
print("Hello, world!")

# %%
random_assortment = ["milk", "cookies", "bread", "honey", "tablet", "computer", "phone"]
print(random_assortment)

# %%
item_costs = {item: 10 for item in random_assortment}
print(item_costs)

# %%
item_quantities = {item: 2 for item in random_assortment}
print(item_quantities)
