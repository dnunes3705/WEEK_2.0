# %% [markdown]
# # 02 ? Bivariate Analysis (UrbanCart)
#
# This notebook contains **bivariate visualizations** aligned to the 3 retention hypotheses (H1?H3).
#
# **Strictly no hypothesis tests** are run here ? only descriptive plots (retention rates by binned feature values).
#
# Dataset used (cleaned):
# - `data/processed/urbancart_customers_features_clean.csv`
#
# _Last generated: 2026-08-01 09:47:18_

# %% [markdown]
# ## Notes
#
# - Retention rates are computed on **eligible cohorts only** (e.g., `eligible_30d=Yes`) to avoid right-censoring bias.
# - For ineligible customers, `retained_30d` / `retained_90d` may be blank; those rows are excluded by the eligibility filter.

# %%
print('Rows in customer features:', 5000)
# Out:
# Rows in customer features: 5,000

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H1: 30-day retention vs delayed_order_share (customer)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; binned share of delayed orders</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H1: 90-day retention vs delayed_order_share (customer)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_90d only; binned share of delayed orders</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H1: 30-day retention vs median_delay_minutes (customer)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; binned median delay</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2=
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H1: 30-day retention vs avg_customer_rating (customer)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; rating buckets</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2='135.0
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H2: 30-day retention vs inaccurate_order_share (customer)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; proxy for fulfillment issues</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' 
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H2: 30-day retention vs low_rating_share (customer)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; dissatisfaction proxy</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2='1
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H3: 30-day retention vs orders_first_14d</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; early engagement</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2='135.0' stroke='#9
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H3: 90-day retention vs orders_first_14d</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_90d only; early engagement</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2='135.0' stroke='#9
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H3: 30-day retention vs days_to_second_order</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; customers with a 2nd order</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2='135
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>H3: 30-day retention vs unique_vendors_first_14d</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Eligible_30d only; early variety</div><svg width='900' height='340' viewBox='0 0 900 340' xmlns='http://www.w3.org/2000/svg'><line x1='64' y1='260' x2='882' y2='260' stroke='#999'/><line x1='64' y1='10' x2='64' y2='260' stroke='#999'/><line x1='60' y1='260.0' x2='64' y2='260.0' stroke='#999'/><text x='56' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.00</text><line x1='64' y1='260.0' x2='882' y2='260.0' stroke='#eee'/><line x1='60' y1='197.5' x2='64' y2='197.5' stroke='#999'/><text x='56' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0.25</text><line x1='64' y1='197.5' x2='882' y2='197.5' stroke='#eee'/><line x1='60' y1='135.0' x2='64' y2='135.0' strok
# ...
