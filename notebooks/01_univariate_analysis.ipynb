# %% [markdown]
# # 01 ? Univariate Analysis (UrbanCart)
#
# This notebook contains **univariate distributions** for key customer-, order-, and delivery-level variables used in descriptive analysis and hypothesis testing.
#
# **Datasets used** (cleaned):
# - `data/processed/urbancart_orders_enriched_clean.csv`
# - `data/processed/urbancart_customers_features_clean.csv`
#
# Plots are rendered as **inline SVG** (no external plotting libraries required).
#
# _Last generated: 2026-08-01 09:30:44_

# %%
import csv
from collections import Counter
from statistics import mean
from pathlib import Path
from datetime import datetime

# This notebook uses inline SVG (no matplotlib/plotly required).
# If you want to regenerate plots, rerun the cells below.

# %%
ORDERS_PATH = Path(r"data\processed\urbancart_orders_enriched_clean.csv")
CUSTOMERS_PATH = Path(r"data\processed\urbancart_customers_features_clean.csv")

# %%
print('Orders rows:', '73,022')
print('Customers rows:', '5,000')
# Out:
# Orders rows: 73,022
# Customers rows: 5,000

# %% [markdown]
# ## Plots
#
# Below are the univariate plots to review. If you want to regenerate them programmatically later, tell me and I can refactor the SVG plotting helpers into a reusable module.

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Customer retention (30d) ? eligible only</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 2 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>983</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='13
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Customer retention (90d) ? eligible only</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 2 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>1093</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='1
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Orders per customer (orders_total)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=5,000, min=1.00, mean=14.60, max=126.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>334</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Avg order value per customer (avg_order_value_usd)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=5,000, min=12.39, mean=51.46, max=167.46</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>292</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Promo order share per customer (promo_order_share)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=5,000, min=0.00, mean=0.40, max=1.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>155</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' s
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Delayed order share per customer (delayed_order_share)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=5,000, min=0.00, mean=0.26, max=1.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>159</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Inaccurate order share per customer (inaccurate_order_share)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=5,000, min=0.00, mean=0.08, max=1.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>563</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Avg rating per customer (avg_customer_rating)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=5,000, min=1.00, mean=3.83, max=5.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>168</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Customers by city (top)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 12 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>115</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Customers by segment</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 3 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>726</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor='en
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Customers by device</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 2 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>966</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor='end
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Orders by vendor_category</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 4 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>9145</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anch
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Orders by delivery_type</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 3 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>10995</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-ancho
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Order value (order_value_usd)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=73,022, min=8.08, mean=51.25, max=342.21</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>3303</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><t
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Items per order (items_count)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=73,022, min=1.00, mean=6.26, max=24.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>2740</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><tex
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Discount percent (discount_pct)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=73,022, min=0.00, mean=0.06, max=0.25</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>10720</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><t
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Delay minutes (delay_minutes)</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>n=73,022, min=0.00, mean=5.01, max=130.00</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>13784</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><t
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Delivery status</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 2 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>13784</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor='end' 
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Order accuracy</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 3 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>16807</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor='end' f
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Customer rating</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 5 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>7165</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor='end' f
# ...

# %%
# plot
# Out:
# <div style='border:1px solid #ddd;border-radius:10px;padding:12px;margin:10px 0;background:#fff'><div style='font:600 16px system-ui;margin:0 0 2px 0'>Delay bucket</div><div style='font:400 12px system-ui;color:#555;margin:0 0 8px 0'>Top 4 categories</div><svg width='820' height='320' viewBox='0 0 820 320' xmlns='http://www.w3.org/2000/svg'><line x1='56' y1='260' x2='802' y2='260' stroke='#999'/><line x1='56' y1='10' x2='56' y2='260' stroke='#999'/><line x1='52' y1='260.0' x2='56' y2='260.0' stroke='#999'/><text x='48' y='264.0' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>0</text><line x1='56' y1='260.0' x2='802' y2='260.0' stroke='#eee'/><line x1='52' y1='197.5' x2='56' y2='197.5' stroke='#999'/><text x='48' y='201.5' text-anchor='end' font-family='system-ui' font-size='10' fill='#444'>13784</text><line x1='56' y1='197.5' x2='802' y2='197.5' stroke='#eee'/><line x1='52' y1='135.0' x2='56' y2='135.0' stroke='#999'/><text x='48' y='139.0' text-anchor='end' fon
# ...
